# %% [markdown]
# # osiris GDELT data

# %% [markdown]
# This notebook describes the [GDELT project](https://www.gdeltproject.org/) data that osiris uses and how to import it using osiris either from the GDELT file server or from Google BigQuery.

# %% [markdown]
# *From the GDELT website*:
# >The GDELT Project is a realtime network diagram and database of global human society for open research.
# ![gf](https://www.gdeltproject.org/images/spinningglobe.gif)
# >The GDELT Project is an initiative to construct a catalog of human societal-scale behavior and beliefs across all countries of the world, connecting every person, organization, location, count, theme, news source, and event across the planet into a single massive network that captures what's happening around the world, what its context is and who's involved, and how the world is feeling about it, every single day.

# %%
# Check if in Coab
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

# %%
# Uncomment and run below if running inside Cobab and you want to pull env variables from a file called vars.env on your GDrive
# !pip install colab-env --upgrade
# import colab_env

# %%
# Uncomment and run below if you need to install osiris in your notebook env e.g. if running inside Colab
# if [ -d "osiris" ]; then rm -Rf osiris; fi
# !git clone https://github.com/allisterb/osiris --recurse-submodules
# !cd osiris && ./install

# %%
# Import the osiris code and set the runtime env. 
import sys
if IN_COLAB:
    sys.path.append(os.path.join('osiris', 'osiris'))
    sys.path.append(os.path.join('osiris', 'ext'))
else: # assuming we're running from the osiris project folder
    sys.path.append(os.path.join('..', 'osiris'))
    sys.path.append(os.path.join('..', 'ext'))
from osiris_global import set_runtime_env
set_runtime_env(interactive_nb=True)

# %% [markdown]
# ## GDELT Event Data

# %% [markdown]
# The GDELT [event data](http://data.gdeltproject.org/documentation/GDELT-Event_Codebook-V2.0.pdf) contains hundreds of millions of automatically coded events extracted from news stories daily. osiris allows you to extract data directly from the GDELT file server/ The advantage of this method is that you don't need to have any special credentials or server access (remember we want *open-source* indicators.). All the data is downloaded directly to your client machine.

# %%
# Import data directly from GDELT file server
from data.gdelt import DataSource
import pandas as pd
gdelt = DataSource()

# %%
# Get event data for a 1 week period
events = gdelt.import_data('events', 'Apr-14-2022', 'Apr-20-2022')
# Out:
# Importing GDELT events data for 7 day(s) from 04-14-2022 to 04-20-2022...
# Import GDELT events data:   0%|          | 0/7 [00:00<?, ?day/s]
# Importing GDELT events data for 7 day(s) from 04-14-2022 to 04-20-2022 completed in 70.02 s.

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 707186 entries, 0 to 125669
# Data columns (total 62 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   GLOBALEVENTID          707186 non-null  int64
#  1   SQLDATE                707186 non-null  int64
#  2   MonthYear              707186 non-null  int64
#  3   Year                   707186 non-null  int64
#  4   FractionDate           707186 non-null  float64
#  5   Actor1Code             640700 non-null  object
#  6   Actor1Name             640700 non-null  object
#  7   Actor1CountryCode      408112 non-null  object
#  8   Actor1KnownGroupCode   9610 non-null    object
#  9   Actor1EthnicCode       3423 non-null    object
#  10  Actor1Religion1Code    10452 non-null   object
#  11  Actor1Religion2Code    2561 non-null    object
#  12  Actor1Type1Code        296023 non-null  object
#  13  Actor1Type2Code        19713 non-null   object
#  14  Actor1Type3Code        495 non-null     object
#  15  Actor2Code             510606 non-null  object
#  16  Actor2Name             510606 non-null  object
#  17  Actor2CountryCode      326768 non-null  object
#  18  Actor2KnownGroupCode   8143 non-null    object
#  19  Actor2EthnicCode       2730 non-null    object
#  20  Actor2Religion1Code    8792 non-null    object
#  21  Actor2Religion2Code    1890 non-null    object
#  22  Actor2Type1Code        231867 non-null  object
#  23  Actor2Type2Code        14110 non-null   object
#  24  Actor2Type3Code        302 non-null     object
#  25  IsRootEvent            707186 non-null  int64
#  26  EventCode              707186 non-null  object
#  27  CAMEOCodeDescription   707186 non-null  object
#  28  EventBaseCode          707186 non-null  object
#  29  EventRootCode          707186 non-null  object
#  30  QuadClass              707186 non-null  int64
#  31  GoldsteinScale         707178 non-null  float64
#  32  NumMentions            707186 non-null  int64
#  33  NumSources             707186 non-null  int64
#  34  NumArticles            707186 non-null  int64
#  35  AvgTone                707186 non-null  float64
#  36  Actor1Geo_Type         707186 non-null  int64
#  37  Actor1Geo_FullName     624744 non-null  object
#  38  Actor1Geo_CountryCode  624882 non-null  object
#  39  Actor1Geo_ADM1Code     624882 non-null  object
#  40  Actor1Geo_ADM2Code     383765 non-null  object
#  41  Actor1Geo_Lat          624744 non-null  float64
#  42  Actor1Geo_Long         624806 non-null  float64
#  43  Actor1Geo_FeatureID    624882 non-null  object
#  44  Actor2Geo_Type         707186 non-null  int64
#  45  Actor2Geo_FullName     498926 non-null  object
#  46  Actor2Geo_CountryCode  499044 non-null  object
#  47  Actor2Geo_ADM1Code     499044 non-null  object
#  48  Actor2Geo_ADM2Code     268160 non-null  object
#  49  Actor2Geo_Lat          498926 non-null  float64
#  50  Actor2Geo_Long         498980 non-null  float64
#  51  Actor2Geo_FeatureID    499044 non-null  object
#  52  ActionGeo_Type         707186 non-null  int64
#  53  ActionGeo_FullName     689433 non-null  object
#  54  ActionGeo_CountryCode  689588 non-null  object
#  55  ActionGeo_ADM1Code     689588 non-null  object
#  56  ActionGeo_ADM2Code     365036 non-null  object
#  57  ActionGeo_Lat          689433 non-null  float64
#  58  ActionGeo_Long         689511 non-null  float64
#  59  ActionGeo_FeatureID    689588 non-null  object
#  60  DATEADDED              707186 non-null  int64
#  61  SOURCEURL              707186 non-null  object
# dtypes: float64(9), int64(13), object(40)
# memory usage: 339.9+ MB

# %% [markdown]
# About a week's worth of event data in 2022 takes up about 400MB RAM.

# %%
events
# Out:
#         GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0          1039303078  20210414     202104  2021     2021.2849        CAN
# 1          1039303079  20210414     202104  2021     2021.2849        CAN
# 2          1039303080  20210414     202104  2021     2021.2849        CHN
# 3          1039303081  20210414     202104  2021     2021.2849        CVL
# 4          1039303082  20210414     202104  2021     2021.2849  MNCUSAMED
# ...               ...       ...        ...   ...           ...        ...
# 125665     1040383216  20220420     202204  2022     2022.3014        cre
# 125666     1040383217  20220420     202204  2022     2022.3014        cre
# 125667     1040383218  20220420     202204  2022     2022.3014        cre
# 125668     1040383219  20220420     202204  2022     2022.3014     telOPP
# 125669     1040383220  20220420     202204  2022     2022.3014        tib
#
#        Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0          CANADA               CAN                  NaN              NaN
# 1          CANADA               CAN                  NaN              NaN
# 2           CHINA               CHN                  NaN              NaN
# 3       SCIENTIST               NaN                  NaN              NaN
# 4          GOOGLE               USA                  NaN              NaN
# ...           ...               ...                  ...              ...
# 125665       CREE               NaN                  NaN              cre
# 125666       CREE               NaN                  NaN              cre
# 125667       CREE               NaN                  NaN              cre
# 125668     TELUGU               NaN                  NaN              tel
# 125669    TIBETAN               NaN                  NaN              tib
#
#         ... ActionGeo_Type                ActionGeo_FullName  \
# 0       ...              4       Port Elgin, Ontario, Canada
# 1       ...              4       Port Elgin, Ontario, Canada
# 2       ...              4         Shanghai, Shanghai, China
# 3       ...              4   Paris, France (general), France
# 4       ...              2         California, United States
# ...     ...            ...                               ...
# 125665  ...              0                               NaN
# 125666  ...              0                               NaN
# 125667  ...              0                               NaN
# 125668  ...              0                               NaN
# 125669  ...              4  Ladakh, Jammu and Kashmir, India
#
#        ActionGeo_CountryCode ActionGeo_ADM1Code ActionGeo_ADM2Code  \
# 0                         CA               CA08              12643
# 1                         CA               CA08              12643
# 2                         CH               CH23              13243
# 3                         FR               FR00              16282
# 4                         US               USCA                NaN
# ...                      ...                ...                ...
# 125665                   NaN                NaN                NaN
# 125666                   NaN                NaN                NaN
# 125667                   NaN                NaN                NaN
# 125668                   NaN                NaN                NaN
# 125669                    IN               IN12              72785
#
#        ActionGeo_Lat ActionGeo_Long ActionGeo_FeatureID       DATEADDED  \
# 0            44.4333      -81.38330             -571576  20220414014500
# 1            44.4333      -81.38330             -571576  20220414014500
# 2            31.2222      121.45800            -1924465  20220414014500
# 3            48.8667        2.33333            -1456928  20220414014500
# 4            36.1700     -119.74600                  CA  20220414014500
# ...              ...            ...                 ...             ...
# 125665           NaN            NaN                 NaN  20220420234500
# 125666           NaN            NaN                 NaN  20220420234500
# 125667           NaN            NaN                 NaN  20220420234500
# 125668           NaN            NaN                 NaN  20220420234500
# 125669       34.5000       77.50000            -2102224  20220420234500
#
#                                                 SOURCEURL
# 0       https://www.lakeshoreadvance.com/news/local-ne...
# 1       https://www.lakeshoreadvance.com/news/local-ne...
# 2       https://news.yahoo.com/zealand-court-rules-all...
# 3       http://www.jordantimes.com/news/features/first...
# 4       https://menafn.com/1104016162/Google-to-invest...
# ...                                                   ...
# 125665  https://www.cjvr.com/2022/04/20/first-nations-...
# 125666  https://www.cjvr.com/2022/04/20/first-nations-...
# 125667  https://www.cjvr.com/2022/04/20/first-nations-...
# 125668  https://www.deccanchronicle.com/nation/politic...
# 125669  https://www.dailyexcelsior.com/dalai-lama-to-v...
#
# [707186 rows x 62 columns]

# %% [markdown]
# A weeks worth of event data has approx. 700K events. Each event in the data is highly denormalized for ease of querying and coded using a hierachical coding system called [CAMEO](http://data.gdeltproject.org/documentation/CAMEO.Manual.1.1b3.pdf) - Conflict and Mediation Event Observations

# %%
events[['EventCode', 'CAMEOCodeDescription']]
# Out:
#        EventCode                               CAMEOCodeDescription
# 0            012                           Make pessimistic comment
# 1            020                        Appeal, not specified below
# 2           0213                    Appeal for judicial cooperation
# 3            043                                       Host a visit
# 4           0311           Express intent to cooperate economically
# ...          ...                                                ...
# 125665       060     Engage in material cooperation, not spec below
# 125666       073                           Provide humanitarian aid
# 125667       090                   Investigate, not specified below
# 125668       043                                       Host a visit
# 125669       030   Express intent to cooperate, not specified below
#
# [707186 rows x 2 columns]

# %% [markdown]
# We can query and filter event data directly using the Pandas dataframe

# %%
# Find all events that were geolocated in Ukraine that have a valid a Lat / Long
uka_events = events[(events.ActionGeo_CountryCode == 'UP')]
uka_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51845 entries, 79 to 125655
# Data columns (total 62 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GLOBALEVENTID          51845 non-null  int64
#  1   SQLDATE                51845 non-null  int64
#  2   MonthYear              51845 non-null  int64
#  3   Year                   51845 non-null  int64
#  4   FractionDate           51845 non-null  float64
#  5   Actor1Code             49230 non-null  object
#  6   Actor1Name             49230 non-null  object
#  7   Actor1CountryCode      38586 non-null  object
#  8   Actor1KnownGroupCode   1402 non-null   object
#  9   Actor1EthnicCode       92 non-null     object
#  10  Actor1Religion1Code    675 non-null    object
#  11  Actor1Religion2Code    281 non-null    object
#  12  Actor1Type1Code        17962 non-null  object
#  13  Actor1Type2Code        1821 non-null   object
#  14  Actor1Type3Code        85 non-null     object
#  15  Actor2Code             44126 non-null  object
#  16  Actor2Name             44126 non-null  object
#  17  Actor2CountryCode      34704 non-null  object
#  18  Actor2KnownGroupCode   1241 non-null   object
#  19  Actor2EthnicCode       63 non-null     object
#  20  Actor2Religion1Code    483 non-null    object
#  21  Actor2Religion2Code    197 non-null    object
#  22  Actor2Type1Code        15328 non-null  object
#  23  Actor2Type2Code        1171 non-null   object
#  24  Actor2Type3Code        29 non-null     object
#  25  IsRootEvent            51845 non-null  int64
#  26  EventCode              51845 non-null  object
#  27  CAMEOCodeDescription   51845 non-null  object
#  28  EventBaseCode          51845 non-null  object
#  29  EventRootCode          51845 non-null  object
#  30  QuadClass              51845 non-null  int64
#  31  GoldsteinScale         51845 non-null  float64
#  32  NumMentions            51845 non-null  int64
#  33  NumSources             51845 non-null  int64
#  34  NumArticles            51845 non-null  int64
#  35  AvgTone                51845 non-null  float64
#  36  Actor1Geo_Type         51845 non-null  int64
#  37  Actor1Geo_FullName     49223 non-null  object
#  38  Actor1Geo_CountryCode  49230 non-null  object
#  39  Actor1Geo_ADM1Code     49230 non-null  object
#  40  Actor1Geo_ADM2Code     33796 non-null  object
#  41  Actor1Geo_Lat          49223 non-null  float64
#  42  Actor1Geo_Long         49225 non-null  float64
#  43  Actor1Geo_FeatureID    49230 non-null  object
#  44  Actor2Geo_Type         51845 non-null  int64
#  45  Actor2Geo_FullName     44121 non-null  object
#  46  Actor2Geo_CountryCode  44126 non-null  object
#  47  Actor2Geo_ADM1Code     44126 non-null  object
#  48  Actor2Geo_ADM2Code     30466 non-null  object
#  49  Actor2Geo_Lat          44121 non-null  float64
#  50  Actor2Geo_Long         44123 non-null  float64
#  51  Actor2Geo_FeatureID    44126 non-null  object
#  52  ActionGeo_Type         51845 non-null  int64
#  53  ActionGeo_FullName     51845 non-null  object
#  54  ActionGeo_CountryCode  51845 non-null  object
#  55  ActionGeo_ADM1Code     51845 non-null  object
#  56  ActionGeo_ADM2Code     37674 non-null  object
#  57  ActionGeo_Lat          51845 non-null  float64
#  58  ActionGeo_Long         51845 non-null  float64
#  59  ActionGeo_FeatureID    51845 non-null  object
#  60  DATEADDED              51845 non-null  int64
#  61  SOURCEURL              51845 non-null  object
# dtypes: float64(9), int64(13), object(40)
# memory usage: 24.9+ MB

# %%
uka_events['CAMEOCodeDescription']
# Out:
# 79         Use conventional military force, not specifie...
# 83                             Consult, not specified below
# 87                                             Make a visit
# 119                            Consult, not specified below
# 121                            Consult, not specified below
#                                 ...
# 125624                               Cooperate economically
# 125625                         Consult, not specified below
# 125648                                    Praise or endorse
# 125651                                    Praise or endorse
# 125655                                         Make a visit
# Name: CAMEOCodeDescription, Length: 51845, dtype: object

# %%
# Plot these events on a map
import folium
from folium.plugins import FastMarkerCluster
uka_map = folium.Map(
    location=[48., 31.], 
    tiles="Stamen Toner",
    zoom_start=6
)
uka_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_053b4ad9a253c3ff432d3840650d24c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_053b4ad9a253c3ff432d3840650d24c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_053b4ad9a253c3ff432d3840650d24c6 = L.map(
#                 &quot;map_053b4ad9a253c3ff432d3840650d24c6&quot;,
#                 {
#                     center: [48.0, 31.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8861717a6246075756788b63bfa24f16 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
uka_events_sample = uka_events.sample(n=100)
for r in uka_events_sample.itertuples():
    m = folium.Marker(location=[r.ActionGeo_Lat, r.ActionGeo_Long],
                      icon=folium.Icon(color="red", icon="info-sign"),
                      tooltip=r.EventCode + ' ' + r.CAMEOCodeDescription
                     )
    m.add_to(uka_map)
uka_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_053b4ad9a253c3ff432d3840650d24c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_053b4ad9a253c3ff432d3840650d24c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_053b4ad9a253c3ff432d3840650d24c6 = L.map(
#                 &quot;map_053b4ad9a253c3ff432d3840650d24c6&quot;,
#                 {
#                     center: [48.0, 31.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8861717a6246075756788b63bfa24f16 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
#
#             var marker_24fd9454f04b1e8486a75027e5d2388a = L.marker(
#                 [50.4333, 30.5167],
#                 {}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
#
#             var icon_98692fdfc5d53839215b1fc7d8e24992 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_24fd9454f04b1e8486a75027e5d2388a.setIcon(icon_98692fdfc5d53839215b1fc7d8e24992);
#
#
#             marker_24fd9454f04b1e8486a75027e5d2388a.bindTooltip(
#                 `&lt;div&gt;
#                      163  Halt negotiations
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_32d27b7786302b498e970c643c969229 = L.marker(
#                 [49.0, 32.0],
#                 {}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
#
#             var icon_74223a3040cb6fcd1097dd7512268cdd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_32d27b7786302b498e970c643c969229.setIcon(icon_74223a3040cb6fcd1097dd7512268cdd);
#
#
#             marker_32d27b7786302b498e970c643c969229.bindTooltip(
#                 `&lt;div&gt;
#                      084  Return, release, not specified below
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a271158caf3fa4a5d1e1d1c954a8668c = L.marker(
#                 [48.0466, 36.7518],
#                 {}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
#
#             var icon_e7cf35d8943d55ad2d4555db780d1a99 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a271158caf3fa4a5d1e1d1c954a8668c.setIcon(icon_e7cf35d8943d55ad2d4555db780d1a99);
#
#
#             marker_a271158caf3fa4a5d1e1d1c954a8668c.bindTooltip(
#                 `&lt;div&gt;
#                      080  Yield, not specified below
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6690208c1a7b6243da6fcff1886e1669 = L.marker(
#                 [49.0, 32.0],
#                 {}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
#
#             var icon_478a0667af16d317ea7a176aa1238e61 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6690208c1a7b6243da6fcff1886e1669.setIcon(icon_478a0667af16d317ea7a176aa1238e61);
#
#
#             marker_6690208c1a7b6243da6fcff1886e1669.bindTooltip(
#                 `&lt;div&gt;
#                      010  Make statement, not specified below
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e7f60d19733bd0d393e66c47fc94bd66 = L.marker(
#                 [50.4333, 30.5167],
#                 {}
#             ).addTo(map_053b4ad9a253c3ff432d3840650d24c6);
#
#
#             var icon_9a25f4456fa9461eca47b4a9aa6ccb24 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;re
